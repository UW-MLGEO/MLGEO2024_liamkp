# %% [markdown]
# # HW1: Basic Python Demo

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Basic Coding Demo
#
# Assignment asks us to:
# * demonstrate your ability to import modules (completed above)
# * declare list and NumPy arrays
# * declare basic python functions
# * make simple Matplotlib figures to be saved in PNGs

# %%
# Declare List
x = [1,2,3,4,5,6,7]

# declare numpy array
y = np.array([1,54,6,23,54,12,34])

# Declare Basic Python Function to add two numbers, print result, and return sum
def add(a,b):
    c = a+b
    print(str(a)+'+'+str(b)+'='+str(c))
    return c

# impliment function from above
number = add(5,6)

# Make Simple Matplotlib figure, save to png
fig,axs = plt.subplots()
axs.plot(x,y)
fig.savefig('demofig.png')
# Out:
# 5+6=11
